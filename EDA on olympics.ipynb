# %% [markdown]
# # Explanatory Data Analysis (Olympic Games)

# %% [markdown]
# ## Data Import and Inspection

# %% [markdown]
# Import the Datasets Summer (__summer.csv__), Winter (__winter.csv__) and dictionary (__dictionary.csv__) and Inspect!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
summer = pd.read_csv("summer.csv")

# %%
winter = pd.read_csv("winter.csv")

# %%
dictionary = pd.read_csv("dictionary.csv")

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Athlete     31165 non-null  object
#  5   Country     31161 non-null  object
#  6   Gender      31165 non-null  object
#  7   Event       31165 non-null  object
#  8   Medal       31165 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
winter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5770 entries, 0 to 5769
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        5770 non-null   int64
#  1   City        5770 non-null   object
#  2   Sport       5770 non-null   object
#  3   Discipline  5770 non-null   object
#  4   Athlete     5770 non-null   object
#  5   Country     5770 non-null   object
#  6   Gender      5770 non-null   object
#  7   Event       5770 non-null   object
#  8   Medal       5770 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 405.8+ KB

# %%
winter
# Out:
#       Year      City     Sport Discipline               Athlete Country  \
# 0     1924  Chamonix  Biathlon   Biathlon           BERTHET, G.     FRA
# 1     1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.     FRA
# 2     1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice     FRA
# 3     1924  Chamonix  Biathlon   Biathlon       VANDELLE, André     FRA
# 4     1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf     SUI
# ...    ...       ...       ...        ...                   ...     ...
# 5765  2014     Sochi    Skiing  Snowboard          JONES, Jenny     GBR
# 5766  2014     Sochi    Skiing  Snowboard       ANDERSON, Jamie     USA
# 5767  2014     Sochi    Skiing  Snowboard    MALTAIS, Dominique     CAN
# 5768  2014     Sochi    Skiing  Snowboard          SAMKOVA, Eva     CZE
# 5769  2014     Sochi    Skiing  Snowboard      TRESPEUCH, Chloe     FRA
#
#      Gender            Event   Medal
# 0       Men  Military Patrol  Bronze
# ...

# %%
dictionary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         201 non-null    object
#  1   Code            201 non-null    object
#  2   Population      196 non-null    float64
#  3   GDP per Capita  176 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 6.4+ KB

# %%
dictionary
# Out:
#              Country Code  Population  GDP per Capita
# 0        Afghanistan  AFG  32526562.0      594.323081
# 1            Albania  ALB   2889167.0     3945.217582
# 2            Algeria  ALG  39666519.0     4206.031232
# 3    American Samoa*  ASA     55538.0             NaN
# 4            Andorra  AND     70473.0             NaN
# ..               ...  ...         ...             ...
# 196          Vietnam  VIE  91703800.0     2111.138024
# 197  Virgin Islands*  ISV    103574.0             NaN
# 198            Yemen  YEM  26832215.0     1406.291651
# 199           Zambia  ZAM  16211767.0     1304.879014
# 200         Zimbabwe  ZIM  15602751.0      924.143819
#
# [201 rows x 4 columns]

# %% [markdown]
# ## Merging and Concatenating

# %% [markdown]
# 1. __Merge__ Summer and Winter (one row for each Medal awarded in any Olympic Games) and save the merged DataFrame in __olympics__.
# 2. An __additional column__ (e.g. "Edition") shall indicate the Edition -> __Summer or Winter__.
# 3. Add the __full Country name__ from dictionary to olympics (e.g. France for FRA).

# %%
summer["edition"] = "summer"

# %%
winter["edition"] = "winter"

# %%
olympics = pd.concat([summer, winter], ignore_index = True)

# %%
olympics
# Out:
#        Year    City     Sport Discipline             Athlete Country Gender  \
# 0      1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1      1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2      1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3      1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4      1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
# ...     ...     ...       ...        ...                 ...     ...    ...
# 36930  2014   Sochi    Skiing  Snowboard        JONES, Jenny     GBR  Women
# 36931  2014   Sochi    Skiing  Snowboard     ANDERSON, Jamie     USA  Women
# 36932  2014   Sochi    Skiing  Snowboard  MALTAIS, Dominique     CAN  Women
# 36933  2014   Sochi    Skiing  Snowboard        SAMKOVA, Eva     CZE  Women
# 36934  2014   Sochi    Skiing  Snowboard    TRESPEUCH, Chloe     FRA  Women
#
#                             Event   Medal edition
# ...

# %%
dictionary.Country = dictionary.Country.str.strip("*")

# %%
keys = dictionary.Code
values = dictionary.Country

# %%
dic = dict(zip(keys,values))

# %%
dic
# Out:
# {'AFG': 'Afghanistan',
#  'ALB': 'Albania',
#  'ALG': 'Algeria',
#  'ASA': 'American Samoa',
#  'AND': 'Andorra',
#  'ANG': 'Angola',
#  'ANT': 'Antigua and Barbuda',
#  'ARG': 'Argentina',
#  'ARM': 'Armenia',
#  'ARU': 'Aruba',
#  'AUS': 'Australia',
#  'AUT': 'Austria',
#  'AZE': 'Azerbaijan',
#  'BAH': 'Bahamas',
#  'BRN': 'Bahrain',
#  'BAN': 'Bangladesh',
#  'BAR': 'Barbados',
#  'BLR': 'Belarus',
#  'BEL': 'Belgium',
#  'BIZ': 'Belize',
#  'BER': 'Bermuda',
#  'BEN': 'Benin',
#  'BHU': 'Bhutan',
#  'BOL': 'Bolivia',
#  'BIH': 'Bosnia and Herzegovina',
#  'BOT': 'Botswana',
#  'BRA': 'Brazil',
#  'IVB': 'British Virgin Islands',
#  'BRU': 'Brunei',
#  'BUL': 'Bulgaria',
#  'BUR': 'Burkina Faso',
#  'BDI': 'Burundi',
#  'CAM': 'Cambodia',
#  'CMR': 'Cameroon',
#  'CAN': 'Canada',
#  'CPV': 'Cape Verde',
#  'CAY': 'Cayman Islands',
#  'CAF': 'Central African Republic',
#  'CHA': 'Chad',
#  'CHI': 'Chile',
#  'CHN': 'China',
#  'COL': 'Colombia',
#  'COM': 'Comoros',
# ...

# %%
olympics.rename(columns = {"Country" : "Code"}, inplace = True)

# %%
olympics["Country"] = olympics.Code.map(dic)

# %%
olympics
# Out:
#        Year    City     Sport Discipline             Athlete Code Gender  \
# 0      1896  Athens  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1      1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2      1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3      1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4      1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
# ...     ...     ...       ...        ...                 ...  ...    ...
# 36930  2014   Sochi    Skiing  Snowboard        JONES, Jenny  GBR  Women
# 36931  2014   Sochi    Skiing  Snowboard     ANDERSON, Jamie  USA  Women
# 36932  2014   Sochi    Skiing  Snowboard  MALTAIS, Dominique  CAN  Women
# 36933  2014   Sochi    Skiing  Snowboard        SAMKOVA, Eva  CZE  Women
# 36934  2014   Sochi    Skiing  Snowboard    TRESPEUCH, Chloe  FRA  Women
#
#                             Event   Medal edition         Country
# ...

# %% [markdown]
# ## Data Cleaning (Part 1)

# %% [markdown]
# 1. Assign appropriate __Column Headers__ to Country Codes (e.g. __"Code"__) and full Country Names (e.g. __"Country"__).
# 2. __Remove Spaces__ from column headers in olympics and dictionary.
# 3. For some Country Codes, there is no corresponding __full Country Name__ available (e.g. for "URS") -> __missing values__ in olympics. Identify these Country Codes and search the Web for the full Country Names. __Replace__ missing values!

# %%
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36935 entries, 0 to 36934
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        36935 non-null  int64
#  1   City        36935 non-null  object
#  2   Sport       36935 non-null  object
#  3   Discipline  36935 non-null  object
#  4   Athlete     36935 non-null  object
#  5   Code        36931 non-null  object
#  6   Gender      36935 non-null  object
#  7   Event       36935 non-null  object
#  8   Medal       36935 non-null  object
#  9   edition     36935 non-null  object
#  10  Country     30568 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 3.1+ MB

# %%
dictionary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         201 non-null    object
#  1   Code            201 non-null    object
#  2   Population      196 non-null    float64
#  3   GDP per Capita  176 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 6.4+ KB

# %%
dictionary.rename(columns = {"GDP per Capita" : "GDP_per_Capita"}, inplace = True)

# %%
dic = {'URS': 'Soviet Union',
 'GDR': 'East Germany',
 'ROU': 'Romania',
 'FRG': 'West Germany',
 'TCH': 'Czechoslovakia',
 'YUG': 'Yugoslavia',
 'EUN': 'Unified Team',
 'EUA': 'Unified Team of Germany',
 'ZZX': 'Mixed teams',
 'SRB': 'Serbia',
 'ANZ': 'Australasia',
 'RU1': 'Russian Empire',
 'MNE': 'Montenegro',
 'TTO': 'Trinidad and Tobago',
 'BOH': 'Bohemia',
 'BWI': 'West Indies Federation',
 'SGP': 'Singapore',
 'IOP': 'Independent Olympic Participants'}

# %%
#olympics.Country = olympics.Code.replace(dic)

# %%
olympics.Country.fillna(olympics.Code.map(dic), inplace = True)

# %% [markdown]
# ## Data Cleaning (Part 2)

# %% [markdown]
# 1. __Remove rows__ from olympics where the Country code is unknown. (Make sure you reset the Index -> RangeIndex)
# 2. Convert the column __Medal__ into an __ordered Categorical__ column ("Bronze" < "Silver" < "Gold")

# %%
lis = olympics.loc[olympics.Code.isna()].index

# %%
lis
# Out:
# Int64Index([29603, 31072, 31091, 31110], dtype='int64')

# %%
olympics.drop(index = lis, inplace = True)

# %%
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36931 entries, 0 to 36934
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        36931 non-null  int64
#  1   City        36931 non-null  object
#  2   Sport       36931 non-null  object
#  3   Discipline  36931 non-null  object
#  4   Athlete     36931 non-null  object
#  5   Code        36931 non-null  object
#  6   Gender      36931 non-null  object
#  7   Event       36931 non-null  object
#  8   Medal       36931 non-null  object
#  9   edition     36931 non-null  object
#  10  Country     36931 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 3.4+ MB

# %%
olympics.reset_index(inplace = True)

# %%
olympics.Medal = olympics.Medal.astype("category")

# %%
olympics.Medal.sort_values()
# Out:
# 36930    Bronze
# 25565    Bronze
# 25562    Bronze
# 25559    Bronze
# 11084    Bronze
#           ...
# 10811    Silver
# 10810    Silver
# 10809    Silver
# 25834    Silver
# 18465    Silver
# Name: Medal, Length: 36931, dtype: category
# Categories (3, object): ['Bronze', 'Gold', 'Silver']

# %%
olympics.Medal.cat.set_categories(["Bronze", "Silver", "Gold"], ordered = True, inplace = True)

# %%
olympics.Medal.sort_values()
# Out:
# 36930    Bronze
# 8916     Bronze
# 15339    Bronze
# 27698    Bronze
# 8919     Bronze
#           ...
# 25833      Gold
# 10807      Gold
# 10806      Gold
# 10804      Gold
# 0          Gold
# Name: Medal, Length: 36931, dtype: category
# Categories (3, object): ['Bronze' < 'Silver' < 'Gold']

# %% [markdown]
# ## What are the most successful countries of all times?

# %% [markdown]
# For the next questions, use Seaborn plots.
# 1. What are the __Top 10__ Countries by __total medals__?
# 2. __Split__ the total medals of Top 10 Countries into __Summer / Winter__. Are there typical Summer/Winter Games Countries?
# 3. __Split__ the total medals of Top 10 Countries into __Gold, Silver, Bronze__.

# %%
a = pd.DataFrame(olympics.groupby("Country").Medal.count().nlargest(n=10))

# %%
a.reset_index(inplace = True)

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale = 2)
sns.barplot(data = a, x = "Country", y = "Medal")
plt.xticks(rotation = 90)
plt.show()

# %%
a = pd.DataFrame(olympics.groupby("Country").Medal.count().nlargest(n=10))

# %%
df = olympics[olympics.Country.isin(a.index)]

# %%
df
# Out:
#        index  Year    City      Sport Discipline             Athlete Code  \
# 0          0  1896  Athens   Aquatics   Swimming       HAJOS, Alfred  HUN
# 6          6  1896  Athens   Aquatics   Swimming       HAJOS, Alfred  HUN
# 11        11  1896  Athens  Athletics  Athletics       LANE, Francis  USA
# 12        12  1896  Athens  Athletics  Athletics    SZOKOLYI, Alajos  HUN
# 13        13  1896  Athens  Athletics  Athletics       BURKE, Thomas  USA
# ...      ...   ...     ...        ...        ...                 ...  ...
# 36924  36928  2014   Sochi     Skiing  Snowboard       KOBER, Amelie  GER
# 36926  36930  2014   Sochi     Skiing  Snowboard        JONES, Jenny  GBR
# 36927  36931  2014   Sochi     Skiing  Snowboard     ANDERSON, Jamie  USA
# 36928  36932  2014   Sochi     Skiing  Snowboard  MALTAIS, Dominique  CAN
# 36930  36934  2014   Sochi     Skiing  Snowboard    TRESPEUCH, Chloe  FRA
#
#       Gender            Event   Medal edition         Country
# ...

# %%
plt.figure(figsize = (12,8))
sns.countplot(data = df, x = "Country", hue = "edition")
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.countplot(data = df, x = "Country", hue = "Medal")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Do GDP, Population and Politics matter?

# %% [markdown]
# 1. Create the __aggregated and merged__ DataFrame with __Top 50 Countries__ . The Column __Total_Games__ shows the __number of Participations__ (as an approximation: determine the number of Editions where Countries have won at least one medal).

# %%
a
# Out:
#                 Medal
# Country
# United States    5238
# Soviet Union     2489
# United Kingdom   1799
# Germany          1665
# France           1548
# Italy            1488
# Sweden           1477
# Canada           1274
# Australia        1204
# Hungary          1091

# %%
top50 = olympics.merge(dictionary, on = "Country", how = "left")[["Country", "Code_x", "Population", "GDP_per_Capita", "Medal", "edition"]]

# %%
a = pd.DataFrame(top50.groupby("Country").Medal.count().nlargest(n=50))
a.head()
# Out:
#                 Medal
# Country
# United States    5238
# Soviet Union     2489
# United Kingdom   1799
# Germany          1665
# France           1548

# %%
top50 = top50[top50.Country.isin(a.index)]

# %%
top50.shape
# Out:
# (35639, 6)

# %%
a = top50.groupby(["Country", "Medal"]).Medal.count().unstack(fill_value = 0)

# %%
top50 = top50.merge(a, on = "Country", how = "left")
top50
# Out:
#               Country Code_x   Population  GDP_per_Capita   Medal edition  \
# 0             Hungary    HUN    9844686.0    12363.543460    Gold  summer
# 1             Austria    AUT    8611088.0    43774.985174  Silver  summer
# 2              Greece    GRE   10823732.0    18002.230578  Bronze  summer
# 3              Greece    GRE   10823732.0    18002.230578    Gold  summer
# 4              Greece    GRE   10823732.0    18002.230578  Silver  summer
# ...               ...    ...          ...             ...     ...     ...
# 35634  United Kingdom    GBR   65138232.0    43875.969614  Bronze  winter
# 35635   United States    USA  321418820.0    56115.718426    Gold  winter
# 35636          Canada    CAN   35851774.0    43248.529909  Silver  winter
# 35637  Czech Republic    CZE   10551219.0    17548.338213    Gold  winter
# 35638          France    FRA   66808385.0    36205.568102  Bronze  winter
#
#        Bronze  Silver  Gold
# 0         359     320   412
# ...

# %%
top50["total"] = top50.Bronze + top50.Silver + top50.Gold

# %%
top50.drop(columns = ["Medal", "Code_x"], inplace = True)

# %%
top50
# Out:
#               Country   Population  GDP_per_Capita edition  Bronze  Silver  \
# 0             Hungary    9844686.0    12363.543460  summer     359     320
# 1             Austria    8611088.0    43774.985174  summer     147     179
# 2              Greece   10823732.0    18002.230578  summer      52      62
# 3              Greece   10823732.0    18002.230578  summer      52      62
# 4              Greece   10823732.0    18002.230578  summer      52      62
# ...               ...          ...             ...     ...     ...     ...
# 35634  United Kingdom   65138232.0    43875.969614  winter     587     632
# 35635   United States  321418820.0    56115.718426  winter    1265    1571
# 35636          Canada   35851774.0    43248.529909  winter     369     435
# 35637  Czech Republic   10551219.0    17548.338213  winter      55      34
# 35638          France   66808385.0    36205.568102  winter     578     526
#
#        Gold  total
# 0       412   1091
# 1       100    426
# ...

# %%
top50.drop(columns = "edition", inplace = True)

# %%
top50.drop_duplicates(inplace = True)

# %%
top50.reset_index(inplace = True, drop = True)

# %%
top50.shape
# Out:
# (50, 7)

# %%
x = pd.DataFrame(olympics.groupby(["Country", "Year", "City"]).Country.count())
x.columns = ["total"]
x.reset_index(inplace = True)
x = pd.DataFrame(x.Country.value_counts())

# %%
x.reset_index(inplace = True)

# %%
x.columns = ["Country","Total_games"]

# %%
x
# Out:
#                               Country  Total_games
# 0                       United States           48
# 1                              France           47
# 2                              Sweden           47
# 3                              Canada           47
# 4                         Switzerland           46
# ..                                ...          ...
# 140  Independent Olympic Participants            1
# 141                           Eritrea            1
# 142                     Cote d'Ivoire            1
# 143                             Gabon            1
# 144                           Bahrain            1
#
# [145 rows x 2 columns]

# %%
top50 = top50.merge(x, on = "Country", how = "left")

# %%
top50.sort_values(by = "total", ascending = False, inplace = True)

# %%
top50.shape
# Out:
# (50, 8)

# %%
top50 = top50[["total", "Gold", "Silver", "Bronze", "Population", "GDP_per_Capita", "Total_games", "Country"]]

# %%
top50.set_index("Country", inplace = True)

# %%
top50.columns = ["Total", "Gold", "Silver", "Bronze", "Populationh", "GDP", "Total_Games"]

# %%
top50
# Out:
#                          Total  Gold  Silver  Bronze   Populationh  \
# Country
# United States             5238  2402    1571    1265  3.214188e+08
# Soviet Union              2489  1088     724     677           NaN
# United Kingdom            1799   580     632     587  6.513823e+07
# Germany                   1665   589     504     572  8.141314e+07
# France                    1548   444     526     578  6.680838e+07
# Italy                     1488   534     473     481  6.080208e+07
# Sweden                    1477   476     496     505  9.798871e+06
# Canada                    1274   470     435     369  3.585177e+07
# Australia                 1204   317     408     479  2.378117e+07
# Hungary                   1091   412     320     359  9.844686e+06
# Russia                    1031   333     328     370  1.440968e+08
# Norway                    1011   368     371     272  5.195921e+06
# East Germany               987   387     321     279           NaN
# ...

# %% [markdown]
# 2. __Convert__ the __absolute values__ in the DataFrame into __ranks__ and save the ranks DataFrame in new variable (see screenshot). Ranks are more meaningful than absolute numbers.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
top50.rank(ascending = False)
# Out:
#                          Total  Gold  Silver  Bronze  Populationh   GDP  \
# Country
# United States              1.0   1.0     1.0     1.0          3.0   4.0
# Soviet Union               2.0   2.0     2.0     2.0          NaN   NaN
# United Kingdom             3.0   4.0     3.0     3.0         14.0   8.0
# Germany                    4.0   3.0     5.0     5.0         10.0  12.0
# France                     5.0   8.0     4.0     4.0         13.0  15.0
# Italy                      6.0   5.0     7.0     7.0         15.0  17.0
# Sweden                     7.0   6.0     6.0     6.0         32.0   6.0
# Canada                     8.0   7.0     8.0    12.0         23.0  10.0
# Australia                  9.0  13.0     9.0     8.0         24.0   3.0
# Hungary                   10.0   9.0    14.0    13.0         31.0  25.0
# Russia                    11.0  12.0    11.0    11.0          7.0  28.0
# Norway                    12.0  11.0    10.0    17.0         39.0   2.0
# ...

# %%
sumVSwin = pd.crosstab(olympics.Country, olympics.edition)

# %%
menVSwomen = pd.crosstab(olympics.Country, olympics.Gender)

# %%
df = pd.concat([sumVSwin, menVSwomen], axis = 1)

# %%
df
# Out:
#                         summer  winter  Men  Women
# Country
# Afghanistan                  2       0    2      0
# Algeria                     15       0   12      3
# Argentina                  259       0  187     72
# Armenia                     11       0   11      0
# Australasia                 29       0   27      2
# ...                        ...     ...  ...    ...
# West Germany               490      94  450    134
# West Indies Federation       5       0    5      0
# Yugoslavia                 435       7  379     63
# Zambia                       2       0    2      0
# Zimbabwe                    23       0    0     23
#
# [145 rows x 4 columns]

# %%
df["total"] = df.summer+df.winter

# %%
df.sort_values("total", ascending = False, inplace = True)

# %%
rank = df.rank(ascending = False, method = "average")

# %% [markdown]
# ## Summer Games vs. Winter Games - does Geographical Location matter?

# %% [markdown]
# __Identify Countries__ that are
# 1. __equally successful__ in Summer and Winter Games
# 2. more successful in __Summer Games__
# 3. more successful in __Winter Games__

# %%
season_diff = rank.summer.sub(rank.winter).sort_values().to_frame()

# %%
plt.figure(figsize = (40,5))
sns.heatmap(season_diff.T)
# Out:
# <AxesSubplot:xlabel='Country'>

# %% [markdown]
# ## Men vs. Women - does Culture & Religion matter?

# %% [markdown]
# __Identify Countries__ where
# 1. Men and Women are __equally successful__
# 2. __Men__ are more successful
# 3. __Women__ are more successful

# %%
gender_diff = rank.Men.sub(rank.Women).sort_values().to_frame()

# %%
plt.figure(figsize = (40,5))
sns.heatmap(gender_diff.T)
# Out:
# <AxesSubplot:xlabel='Country'>

# %% [markdown]
# ## Do Traditions matter?

# %% [markdown]
# Create a __Seaborn Heatmap__ that shows the __Ranks__ of Top 50 Countries __by Sports__. <br>
# Identify traditional Sports / National Sports for e.g. UK and China!

# %%
sports_data = pd.crosstab(olympics.Country, olympics.Sport, margins = True).sort_values(by = "All", ascending  = False)

# %%
sports_data.drop(index = ["All"],columns = ["All"], inplace = True)

# %%
sports_rank = sports_data.rank(ascending = False, method = "average")

# %%
sports_rank_20= sports_rank.head(20)

# %%
sports_rank_20
# Out:
# Sport           Aquatics  Archery  Athletics  Badminton  Baseball  Basketball  \
# Country
# United States        1.0      2.0        1.0       78.0       2.0         1.0
# Soviet Union         4.0     10.5        3.0       78.0      76.0         2.0
# United Kingdom      10.5      7.0        2.0        6.0      76.0        83.0
# Germany              5.0     13.0        7.0       78.0      76.0        83.0
# France              14.0      4.0        8.0       78.0      76.0         6.0
# Italy               12.0      6.0       14.0       78.0      76.0        14.0
# Sweden              15.0     20.0        9.0       78.0      76.0        83.0
# Canada              13.0     84.0       12.5       78.0      76.0        20.0
# Australia            2.0     20.0       12.5       78.0       5.0         4.5
# Hungary              3.0     84.0       18.5       78.0      76.0        83.0
# Russia               8.0     22.0       10.0        7.5      76.0         9.0
# ...

# %%
plt.figure(figsize = (40,20))
sns.heatmap(sports_rank_20,cmap='RdYlGn_r', vmin = 1, vmax = 6, linewidth = 1)
# Out:
# <AxesSubplot:xlabel='Sport', ylabel='Country'>
